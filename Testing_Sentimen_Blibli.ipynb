# %% [markdown]
# # Pengujian Model

# %% [markdown]
# ## Import File svm_model dan tfidf_vectorizer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1. Install Library

# %%
# !pip install nltk

# %% [markdown]
# ## 2. Import Library

# %%
import re
import joblib
import nltk


from nltk.corpus import stopwords

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## 3. Load Model

# %%
import joblib

model = joblib.load('/content/drive/MyDrive/svm_model.pkl')
vectorizer = joblib.load('/content/drive/MyDrive/tfidf_vectorizer.pkl')

# %% [markdown]
# ## 4. Preprocessing

# %%
stop_words = set(stopwords.words('indonesian'))

def preprocess(text):
    text = text.lower()
    text = re.sub(r'http\S+|www\S+', '', text)
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    words = text.split()
    words = [word for word in words if word not in stop_words]

    return ' '.join(words)

# %% [markdown]
# ## 5. Input Review

# %%
review_baru = [
    "Aplikasi sangat bagus dan membantu proses belanja",
    "Customer Service nya kurang respon rada kecewa",
    "Aplikasi nya cukup baik "
]

# %% [markdown]
# ## 6. Preprocessing Review

# %%
review_clean = [preprocess(review) for review in review_baru]

# %% [markdown]
# ## 7. TF-IDF

# %%
review_tfidf = vectorizer.transform(review_clean)

# %% [markdown]
# ## 8. Prediksi

# %%
prediksi = model.predict(review_tfidf)

# %% [markdown]
# ## 9. Hasil

# %%
for review, hasil in zip(review_baru, prediksi):
    print(f"Review    : {review}")
    print(f"Sentimen  : {hasil}")
    print("-" * 50)
# Out:
# Review    : Aplikasi sangat bagus dan membantu proses belanja
# Sentimen  : Positif
# --------------------------------------------------
# Review    : Customer Service nya kurang respon rada kecewa
# Sentimen  : Negatif
# --------------------------------------------------
# Review    : Aplikasi nya cukup baik
# Sentimen  : Netral
# --------------------------------------------------
